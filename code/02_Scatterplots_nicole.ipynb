# %%
# Libaries
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Define the new working directory path
new_working_directory = r'/Users/nicol1/Documents/GitHub/sports-data'

# Change the current working directory
os.chdir(new_working_directory)

# %%
# Define the path 
data_folder = 'data/'

# Load the CSV files to df
cleaned_df = pd.read_csv(data_folder + 'cleaned_df.csv')
cleaned_df
# Out:
#        player_id                     name competition_id    country  height  \
# 0         122011         Markus Henriksen            ELQ     Norway   187.0
# 1          14940               Razvan Rat           UKRS    Romania   179.0
# 2          14942              Darijo Srna           UKRS    Croatia   182.0
# 3          26267              Fernandinho           UKRS     Brazil   179.0
# 4          55735       Henrikh Mkhitaryan           UKRS    Armenia   177.0
# ...          ...                      ...            ...        ...     ...
# 25919     330126          Karol Świderski            IT1     Poland   184.0
# 25920      26485           Jérôme Boateng            IT1    Germany   192.0
# 25921     470422  Triantafyllos Pasalidis            IT1     Greece   185.0
# 25922     872184            Tadeo Allende            ES1  Argentina   183.0
# 25923     277179                 Angeliño            IT1      Spain   171.0
#
#         foot  position  highest_market_value  number_games_played  \
# 0      right  Defender             5000000.0                  165
# 1       left  Defender             6500000.0                   97
# 2      right  Defender            17500000.0                  227
# 3      right  Midfield            32000000.0                  399
# 4       both  Midfield            37000000.0                  485
# ...      ...       ...                   ...                  ...
# 25919   left    Attack             6000000.0                   89
# 25920  right  Defender            45000000.0                  351
# 25921  right  Defender             1000000.0                  142
# 25922  right    Attack             4500000.0                    1
# 25923   left  Defender            35000000.0                  244
#
#        total_minutes  ...  red_cards_sum  red_cards_avg  goals  \
# 0              12199  ...              1       0.006061     33
# 1               7690  ...              1       0.010309      3
# 2              19598  ...              2       0.008811     22
# 3              30325  ...              3       0.007519     29
# 4              35878  ...              0       0.000000    128
# ...              ...  ...            ...            ...    ...
# 25919           4336  ...              0       0.000000     28
# 25920          27803  ...              5       0.014245     10
# 25921          11424  ...              1       0.007042      3
# 25922             17  ...              0       0.000000      0
# 25923          20430  ...              0       0.000000     18
#
#        avg_goals_per_game  assists   age  year  avg_games_per_year  \
# 0                0.200000       22  45.0     6           27.500000
# 1                0.030928       13  43.0     5           19.400000
# 2                0.096916       68  45.0     8           28.375000
# 3                0.072682       41  42.0    11           36.272727
# 4                0.263918      119  43.0    13           37.307692
# ...                   ...      ...   ...   ...                 ...
# 25919            0.314607       10   NaN     5           17.800000
# 25920            0.028490       26   NaN    13           27.000000
# 25921            0.021127        2   NaN     8           17.750000
# 25922            0.000000        0   NaN     1            1.000000
# 25923            0.073770       61   NaN     9           27.111111
#
#        avg_goals_per_year  avg_assists_per_year
# 0                5.500000              3.666667
# 1                0.600000              2.600000
# 2                2.750000              8.500000
# 3                2.636364              3.727273
# 4                9.846154              9.153846
# ...                   ...                   ...
# 25919            5.600000              2.000000
# 25920            0.769231              2.000000
# 25921            0.375000              0.250000
# 25922            0.000000              0.000000
# 25923            2.000000              6.777778
#
# [25924 rows x 23 columns]

# %%
# Filter the position for goalkeeper
goalkeeper_df = cleaned_df[cleaned_df['position'] == 'Goalkeeper']
goalkeeper_df
#print(goalkeeper_df.head)
# Out:
#        player_id                name competition_id    country  height   foot  \
# 24         48015      Lukas Hradecky            DK1    Finland   192.0  right
# 27        107775     Frederik Rönnow            DK1    Denmark   188.0  right
# 45         14937     Stipe Pletikosa            RU1    Croatia   193.0  right
# 50         12518        Silvio Proto           BESC    Belgium   184.0  right
# 60         69001  Giedrius Arlauskis            RU1  Lithuania   191.0   left
# ...          ...                 ...            ...        ...     ...    ...
# 25867     226073           Ivo Grbic            FAC    Croatia   195.0  right
# 25884     336077      Altay Bayındır            FAC     Turkey   198.0  right
# 25887     226073           Ivo Grbic            GB1    Croatia   195.0  right
# 25893     667991    Alaa Bellaarouch            FR1    Morocco   188.0  right
# 25913     127202           Matz Sels            GB1    Belgium   188.0  right
#
#          position  highest_market_value  number_games_played  total_minutes  \
# 24     Goalkeeper            12000000.0                  469          42378
# 27     Goalkeeper             5500000.0                  279          25042
# 45     Goalkeeper             6800000.0                   98           8822
# 50     Goalkeeper             4200000.0                  199          17889
# 60     Goalkeeper             2500000.0                   12            923
# ...           ...                   ...                  ...            ...
# 25867  Goalkeeper             7000000.0                   43           3673
# 25884  Goalkeeper            16000000.0                  155          13962
# 25887  Goalkeeper             7000000.0                   43           3673
# 25893  Goalkeeper              200000.0                    1             90
# 25913  Goalkeeper             8000000.0                  305          27405
#
#        ...  red_cards_sum  red_cards_avg  goals  avg_goals_per_game  assists  \
# 24     ...              2       0.004264      0                 0.0        0
# 27     ...              1       0.003584      0                 0.0        0
# 45     ...              0       0.000000      0                 0.0        0
# 50     ...              1       0.005025      0                 0.0        1
# 60     ...              0       0.000000      0                 0.0        0
# ...    ...            ...            ...    ...                 ...      ...
# 25867  ...              0       0.000000      0                 0.0        0
# 25884  ...              0       0.000000      0                 0.0        1
# 25887  ...              0       0.000000      0                 0.0        0
# 25893  ...              0       0.000000      0                 0.0        0
# 25913  ...              0       0.000000      0                 0.0        1
#
#         age  year  avg_games_per_year  avg_goals_per_year  \
# 24     42.0    13           36.076923                 0.0
# 27      NaN    12           23.250000                 0.0
# 45     41.0     5           19.600000                 0.0
# 50     44.0     9           22.111111                 0.0
# 60      NaN     4            3.000000                 0.0
# ...     ...   ...                 ...                 ...
# 25867   NaN     5            8.600000                 0.0
# 25884   NaN     7           22.142857                 0.0
# 25887   NaN     5            8.600000                 0.0
# 25893   NaN     1            1.000000                 0.0
# 25913   NaN    13           23.461538                 0.0
#
#        avg_assists_per_year
# 24                 0.000000
# 27                 0.000000
# 45                 0.000000
# 50                 0.111111
# 60                 0.000000
# ...                     ...
# 25867              0.000000
# 25884              0.142857
# 25887              0.000000
# 25893              0.000000
# 25913              0.076923
#
# [2033 rows x 23 columns]

# %%
# Filter for Defender
defender_df = cleaned_df[cleaned_df['position'] == 'Defender']
defender_df
# Out:
#        player_id                     name competition_id  country  height  \
# 0         122011         Markus Henriksen            ELQ   Norway   187.0
# 1          14940               Razvan Rat           UKRS  Romania   179.0
# 2          14942              Darijo Srna           UKRS  Croatia   182.0
# 12         42678      Salvatore Bocchetti           RUSS    Italy   186.0
# 13         44136        Domenico Criscito           RUSS    Italy   183.0
# ...          ...                      ...            ...      ...     ...
# 25912     355627            Sergio Akieme            FR1    Spain   172.0
# 25917     787912   El Chadaille Bitshiabu             L1   France   196.0
# 25920      26485           Jérôme Boateng            IT1  Germany   192.0
# 25921     470422  Triantafyllos Pasalidis            IT1   Greece   185.0
# 25923     277179                 Angeliño            IT1    Spain   171.0
#
#         foot  position  highest_market_value  number_games_played  \
# 0      right  Defender             5000000.0                  165
# 1       left  Defender             6500000.0                   97
# 2      right  Defender            17500000.0                  227
# 12      left  Defender            14000000.0                  149
# 13      left  Defender            16000000.0                  301
# ...      ...       ...                   ...                  ...
# 25912   left  Defender             9000000.0                   51
# 25917   left  Defender            15000000.0                   16
# 25920  right  Defender            45000000.0                  351
# 25921  right  Defender             1000000.0                  142
# 25923   left  Defender            35000000.0                  244
#
#        total_minutes  ...  red_cards_sum  red_cards_avg  goals  \
# 0              12199  ...              1       0.006061     33
# 1               7690  ...              1       0.010309      3
# 2              19598  ...              2       0.008811     22
# 12             12830  ...              1       0.006711      8
# 13             25208  ...              1       0.003322     39
# ...              ...  ...            ...            ...    ...
# 25912           4199  ...              0       0.000000      4
# 25917            632  ...              0       0.000000      0
# 25920          27803  ...              5       0.014245     10
# 25921          11424  ...              1       0.007042      3
# 25923          20430  ...              0       0.000000     18
#
#        avg_goals_per_game  assists   age  year  avg_games_per_year  \
# 0                0.200000       22  45.0     6           27.500000
# 1                0.030928       13  43.0     5           19.400000
# 2                0.096916       68  45.0     8           28.375000
# 12               0.053691        1  43.0     9           16.555556
# 13               0.129568       31  46.0    11           27.363636
# ...                   ...      ...   ...   ...                 ...
# 25912            0.078431        1   NaN     5           10.200000
# 25917            0.000000        0   NaN     3            5.333333
# 25920            0.028490       26   NaN    13           27.000000
# 25921            0.021127        2   NaN     8           17.750000
# 25923            0.073770       61   NaN     9           27.111111
#
#        avg_goals_per_year  avg_assists_per_year
# 0                5.500000              3.666667
# 1                0.600000              2.600000
# 2                2.750000              8.500000
# 12               0.888889              0.111111
# 13               3.545455              2.818182
# ...                   ...                   ...
# 25912            0.800000              0.200000
# 25917            0.000000              0.000000
# 25920            0.769231              2.000000
# 25921            0.375000              0.250000
# 25923            2.000000              6.777778
#
# [8742 rows x 23 columns]

# %%
# Filter for Midfield
midfield_df = cleaned_df[cleaned_df['position'] == 'Midfield']
midfield_df
# Out:
#        player_id                name competition_id        country  height  \
# 3          26267         Fernandinho           UKRS         Brazil   179.0
# 4          55735  Henrikh Mkhitaryan           UKRS        Armenia   177.0
# 9          54576    Sebastián Blanco           UKR1      Argentina   168.0
# 10         48740      Milos Ninkovic           UKR1         Serbia   180.0
# 17         18091       Derek Boateng           UKR1          Ghana     NaN
# ...          ...                 ...            ...            ...     ...
# 25894     405690        Ole Pohlmann             L1        Germany   183.0
# 25897     744149        Adam Wharton            GB1        England   182.0
# 25905     263804            Pep Biel             L1          Spain   172.0
# 25914     504215      Giovanni Reyna            GB1  United States   185.0
# 25918     748319      Carlos Alcaraz            IT1      Argentina   183.0
#
#         foot  position  highest_market_value  number_games_played  \
# 3      right  Midfield            32000000.0                  399
# 4       both  Midfield            37000000.0                  485
# 9       both  Midfield             6000000.0                   71
# 10     right  Midfield             5500000.0                   41
# 17       NaN  Midfield             4500000.0                   21
# ...      ...       ...                   ...                  ...
# 25894  right  Midfield              700000.0                    1
# 25897   left  Midfield            10000000.0                    4
# 25905   left  Midfield             6000000.0                  145
# 25914  right  Midfield            42000000.0                  122
# 25918  right  Midfield            15000000.0                   23
#
#        total_minutes  ...  red_cards_sum  red_cards_avg  goals  \
# 3              30325  ...              3       0.007519     29
# 4              35878  ...              0       0.000000    128
# 9               3802  ...              1       0.014085     11
# 10              2624  ...              0       0.000000      2
# 17              1253  ...              0       0.000000      0
# ...              ...  ...            ...            ...    ...
# 25894             31  ...              0       0.000000      0
# 25897            317  ...              0       0.000000      0
# 25905           9496  ...              0       0.000000     35
# 25914           5144  ...              0       0.000000     17
# 25918           1336  ...              0       0.000000      5
#
#        avg_goals_per_game  assists   age  year  avg_games_per_year  \
# 3                0.072682       41  42.0    11           36.272727
# 4                0.263918      119  43.0    13           37.307692
# 9                0.154930        8  42.0     3           23.666667
# 10               0.048780        3  43.0     4           10.250000
# 17               0.000000        0  47.0     4            5.250000
# ...                   ...      ...   ...   ...                 ...
# 25894            0.000000        0   NaN     1            1.000000
# 25897            0.000000        0   NaN     2            2.000000
# 25905            0.241379       28   NaN     6           24.166667
# 25914            0.139344       16   NaN     5           24.400000
# 25918            0.217391        4   NaN     2           11.500000
#
#        avg_goals_per_year  avg_assists_per_year
# 3                2.636364              3.727273
# 4                9.846154              9.153846
# 9                3.666667              2.666667
# 10               0.500000              0.750000
# 17               0.000000              0.000000
# ...                   ...                   ...
# 25894            0.000000              0.000000
# 25897            0.000000              0.000000
# 25905            5.833333              4.666667
# 25914            3.400000              3.200000
# 25918            2.500000              2.000000
#
# [7805 rows x 23 columns]

# %%
# Filter for Striker
striker_df = cleaned_df[cleaned_df['position'] == 'Attack']
striker_df
# Out:
#        player_id                name competition_id        country  height  \
# 5          75615       Douglas Costa           UKRS         Brazil   172.0
# 6          73185         Lucas Pérez           UKR1          Spain   180.0
# 7         119169     Aron Jóhannsson            DK1  United States   184.0
# 8          53477  Jonathan Cristaldo           UKR1      Argentina   174.0
# 11          2050       Nelson Valdez           RUSS       Paraguay   179.0
# ...          ...                 ...            ...            ...     ...
# 25911     599663     Faris Moumbagna            FR1       Cameroon   185.0
# 25915     726701     Rodrigo Ribeiro            GB1       Portugal   185.0
# 25916     409517     Yorbe Vertessen             L1        Belgium   176.0
# 25919     330126     Karol Świderski            IT1         Poland   184.0
# 25922     872184       Tadeo Allende            ES1      Argentina   183.0
#
#         foot position  highest_market_value  number_games_played  \
# 5       left   Attack            55000000.0                  308
# 6       left   Attack            17000000.0                  311
# 7      right   Attack             4000000.0                  132
# 8      right   Attack             5500000.0                   70
# 11     right   Attack             5000000.0                   69
# ...      ...      ...                   ...                  ...
# 25911   left   Attack             7000000.0                   20
# 25915  right   Attack             3000000.0                    3
# 25916  right   Attack             4500000.0                  112
# 25919   left   Attack             6000000.0                   89
# 25922  right   Attack             4500000.0                    1
#
#        total_minutes  ...  red_cards_sum  red_cards_avg  goals  \
# 5              17779  ...              1       0.003247     44
# 6              21720  ...              0       0.000000     87
# 7               8280  ...              1       0.007576     57
# 8               4381  ...              1       0.014286     20
# 11              2881  ...              0       0.000000     16
# ...              ...  ...            ...            ...    ...
# 25911           1069  ...              0       0.000000      4
# 25915             28  ...              0       0.000000      0
# 25916           3611  ...              0       0.000000     21
# 25919           4336  ...              0       0.000000     28
# 25922             17  ...              0       0.000000      0
#
#        avg_goals_per_game  assists   age  year  avg_games_per_year  \
# 5                0.142857       74  43.0    10           30.800000
# 6                0.279743       57  47.0    11           28.272727
# 7                0.431818       16  42.0     8           16.500000
# 8                0.285714        5  45.0     3           23.333333
# 11               0.231884        0  43.0     4           17.250000
# ...                   ...      ...   ...   ...                 ...
# 25911            0.200000        2   NaN     4            5.000000
# 25915            0.000000        0   NaN     2            1.500000
# 25916            0.187500       13   NaN     5           22.400000
# 25919            0.314607       10   NaN     5           17.800000
# 25922            0.000000        0   NaN     1            1.000000
#
#        avg_goals_per_year  avg_assists_per_year
# 5                4.400000              7.400000
# 6                7.909091              5.181818
# 7                7.125000              2.000000
# 8                6.666667              1.666667
# 11               4.000000              0.000000
# ...                   ...                   ...
# 25911            1.000000              0.500000
# 25915            0.000000              0.000000
# 25916            4.200000              2.600000
# 25919            5.600000              2.000000
# 25922            0.000000              0.000000
#
# [7320 rows x 23 columns]

# %%
# Scatterplot goalkeeper 

# height
plt.scatter(goalkeeper_df['height'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('Height')
plt.show()

# age
plt.scatter(goalkeeper_df['age'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('Age')
plt.show()

# year
plt.scatter(goalkeeper_df['year'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('number of seasons')
plt.show()

# average minutes
plt.scatter(goalkeeper_df['average_minutes'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('Average Minutes played')
plt.show()

# red cards average
plt.scatter(goalkeeper_df['red_cards_avg'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('Average Red Cards per game')
plt.show()

# yellow cards average
plt.scatter(goalkeeper_df['yellow_cards_avg'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('Average yellow cards per game')
plt.show()

# average assists
plt.scatter(goalkeeper_df['avg_assists_per_year'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('average assists per game')
plt.show()

# average goals
plt.scatter(goalkeeper_df['avg_goals_per_year'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('average goals per game')
plt.show()

# average games per year
plt.scatter(goalkeeper_df['avg_games_per_year'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('average games played per season')
plt.show()

# League
plt.scatter(goalkeeper_df['competition_id'], goalkeeper_df['highest_market_value'], c ="pink")
plt.title('League')
plt.show()

# Country
#plt.scatter(goalkeeper_df['country'], goalkeeper_df['highest_market_value'], c ="pink")
#plt.title('Nationalaty')
#plt.show()

# foot
#plt.scatter(goalkeeper_df['foot'], goalkeeper_df['highest_market_value'], c ="pink")
#plt.title('Foot')
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 59
#      51 plt.show()
#      53 # Country
#      54 #plt.scatter(goalkeeper_df['country'], goalkeeper_df['highest_market_value'], c ="pink")
#      55 #plt.title('Nationalaty')
#      56 #plt.show()
#      57
#      58 # foot
# ---> 59 plt.scatter(goalkeeper_df['foot'], goalkeeper_df['highest_market_value'], c ="pink")
#      60 plt.title('Foot')
#      61 plt.show()
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2865         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2866         **({"data": data} if data is not None else {}), **kwargs)
#    2867     sci(__ret)
#    2868     return __ret
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py:4572, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4462 """
#    4463 A scatter plot of *y* vs. *x* with varying marker size and/or color.
#    4464
#    (...)
#    4569
#    4570 """
#    4571 # Process **kwargs to handle aliases, conflicts with explicit kwargs:
# -> 4572 x, y = self._process_unit_info([("x", x), ("y", y)], kwargs)
#    4573 # np.ma.ravel yields an ndarray, not a masked array,
#    4574 # unless its argument is a masked array.
#    4575 x = np.ma.ravel(x)
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/axes/_base.py:2549, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2547     # Update from data if axis is already set but no unit is set yet.
#    2548     if axis is not None and data is not None and not axis.have_units():
# -> 2549         axis.update_units(data)
#    2550 for axis_name, axis in axis_map.items():
#    2551     # Return if no axis is set.
#    2552     if axis is None:
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/axis.py:1713, in Axis.update_units(self, data)
#    1711 neednew = self.converter != converter
#    1712 self.converter = converter
# -> 1713 default = self.converter.default_units(data, self)
#    1714 if default is not None and self.units is None:
#    1715     self.set_units(default)
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/category.py:105, in StrCategoryConverter.default_units(data, axis)
#     103 # the conversion call stack is default_units -> axis_info -> convert
#     104 if axis.units is None:
# --> 105     axis.set_units(UnitData(data))
#     106 else:
#     107     axis.units.update(data)
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/category.py:181, in UnitData.__init__(self, data)
#     179 self._counter = itertools.count()
#     180 if data is not None:
# --> 181     self.update(data)
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/category.py:216, in UnitData.update(self, data)
#     213 convertible = True
#     214 for val in OrderedDict.fromkeys(data):
#     215     # OrderedDict just iterates over unique values in data.
# --> 216     _api.check_isinstance((str, bytes), value=val)
#     217     if convertible:
#     218         # this will only be called so long as convertible is True.
#     219         convertible = self._str_is_convertible(val)
#
# File ~/Documents/GitHub/sports-data/.venv/lib/python3.8/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'value' must be an instance of str or bytes, not a float

# %% [markdown]
# # Notes to plots for goalkeepers
# it seems like average games played within a season is the strongest factor influencing the market value. With the other plots it is difficult to see a relation (linear).

# %%
# Scatterplot Defense

# height
plt.scatter(defender_df['height'], defender_df['highest_market_value'], c ="pink")
plt.title('height')
plt.show()

# age
plt.scatter(defender_df['age'], defender_df['highest_market_value'], c ="pink")
plt.title('age')
plt.show()

# year
plt.scatter(defender_df['year'], defender_df['highest_market_value'], c ="pink")
plt.title('number of seasons')
plt.show()

# average minutes
plt.scatter(defender_df['average_minutes'], defender_df['highest_market_value'], c ="pink")
plt.title('average minutes played per game')
plt.show()

# red cards average
plt.scatter(defender_df['red_cards_avg'], defender_df['highest_market_value'], c ="pink")
plt.title('average red cards per game')
plt.show()

# yellow cards average
plt.scatter(defender_df['red_cards_avg'], defender_df['highest_market_value'], c ="pink")
plt.title('average yellow cards per game')
plt.show()

# average assists
plt.scatter(defender_df['avg_assists_per_year'], defender_df['highest_market_value'], c ="pink")
plt.title('average assists per game')
plt.show()

# average goals
plt.scatter(defender_df['avg_goals_per_year'], defender_df['highest_market_value'], c ="pink")
plt.title('average goals per game')
plt.show()

# average games per year
plt.scatter(defender_df['avg_games_per_year'], defender_df['highest_market_value'], c ="pink")
plt.title('average games per year')
plt.show()

# League
plt.scatter(defender_df['competition_id'], defender_df['highest_market_value'], c ="pink")
plt.title('League')
plt.show()

# %%
# Scatterplot Midfield

# height
plt.scatter(midfield_df['height'], midfield_df['highest_market_value'], c ="pink")
plt.title('height')
plt.show()

# age
plt.scatter(midfield_df['age'], midfield_df['highest_market_value'], c ="pink")
plt.title('age')
plt.show()

# year
plt.scatter(midfield_df['year'], midfield_df['highest_market_value'], c ="pink")
plt.title('number of seasons')
plt.show()

# average minutes
plt.scatter(midfield_df['average_minutes'], midfield_df['highest_market_value'], c ="pink")
plt.title('average minutes played per game')
plt.show()

# red cards average
plt.scatter(midfield_df['red_cards_avg'], midfield_df['highest_market_value'], c ="pink")
plt.title('average red cards per game')
plt.show()

# yellow cards average
plt.scatter(midfield_df['red_cards_avg'], midfield_df['highest_market_value'], c ="pink")
plt.title('average yellow cards per game')
plt.show()

# average assists
plt.scatter(midfield_df['avg_assists_per_year'], midfield_df['highest_market_value'], c ="pink")
plt.title('average assists per game')
plt.show()

# average goals
plt.scatter(midfield_df['avg_goals_per_year'], midfield_df['highest_market_value'], c ="pink")
plt.title('average goals per game')
plt.show()

# average games per year
plt.scatter(midfield_df['avg_games_per_year'], midfield_df['highest_market_value'], c ="pink")
plt.title('average games per year')
plt.show()

# League
plt.scatter(midfield_df['competition_id'], midfield_df['highest_market_value'], c ="pink")
plt.title('League')
plt.show()

# %%
# Scatterplot striker

# height
plt.scatter(striker_df['height'], striker_df['highest_market_value'], c ="pink")
plt.title('height')
plt.show()

# age
plt.scatter(striker_df['age'], striker_df['highest_market_value'], c ="pink")
plt.title('age')
plt.show()

# year
plt.scatter(striker_df['year'], striker_df['highest_market_value'], c ="pink")
plt.title('number of seasons')
plt.show()

# average minutes
plt.scatter(striker_df['average_minutes'], striker_df['highest_market_value'], c ="pink")
plt.title('average minutes played per game')
plt.show()

# red cards average
plt.scatter(striker_df['red_cards_avg'], striker_df['highest_market_value'], c ="pink")
plt.title('average red cards per game')
plt.show()

# yellow cards average
plt.scatter(striker_df['red_cards_avg'], striker_df['highest_market_value'], c ="pink")
plt.title('average yellow cards per game')
plt.show()

# average assists
plt.scatter(striker_df['avg_assists_per_year'], striker_df['highest_market_value'], c ="pink")
plt.title('average assists per game')
plt.show()

# average goals
plt.scatter(striker_df['avg_goals_per_year'], striker_df['highest_market_value'], c ="pink")
plt.title('average goals per game')
plt.show()

# average games per year
plt.scatter(striker_df['avg_games_per_year'], striker_df['highest_market_value'], c ="pink")
plt.title('average games per year')
plt.show()

# League
plt.scatter(striker_df['competition_id'], striker_df['highest_market_value'], c ="pink")
plt.title('League')
plt.show()

# %% [markdown]
# # Notes Striker Plots
# Here we see a relation between the market value and the factors: average minutes played per game, average assists per game, average assists per game, average goals per game, average games per season
