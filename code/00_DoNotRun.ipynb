# %% [markdown]
# The code provided is for demonstration purposes only and should not be run as-is. It was initially used to filter large datasets that are too big to be uploaded to GitHub.

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import pandas as pd

# Define the path to the data folder
data_folder = 'data/original/'

# Load the CSV files into pandas dataframes
appearances_df = pd.read_csv(data_folder + 'appearances.csv')
clubs_df = pd.read_csv(data_folder + 'clubs.csv')
players_df = pd.read_csv(data_folder + 'players.csv')

# %% [markdown]
# # Players

# %%
#players
players_df.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...   foot height_in_cm contract_expiration_date  \
# ...

# %%
len(players_df)
# Out:
# 30465

# %%
# Assumption: the top players are in the following clubs
# Define the list of competition IDs you want to include
competition_ids = ['GB1', 'IT1', 'ES1', 'L1', 'FR1']

# Filter the players_df DataFrame
players_df_filtered = players_df[players_df['current_club_domestic_competition_id'].isin(competition_ids)]

# %%
columns_players = [
    'name',
    'current_club_id',
    'country_of_citizenship',
    'date_of_birth',
    'position',
    'foot', 
    'height_in_cm',
    'market_value_in_eur',
    'highest_market_value_in_eur',
    'player_id'
]

# %%
players_df_filtered = players_df_filtered[columns_players]

# %%
players_df_filtered
# Out:
#                       name  current_club_id country_of_citizenship  \
# 0           Miroslav Klose              398                Germany
# 1       Roman Weidenfeller               16                Germany
# 3                    Lúcio              506                 Brazil
# 4               Tom Starke               27                Germany
# 6      Christoph Metzelder               33                Germany
# ...                    ...              ...                    ...
# 30421     Yunus Emre Konak             1148                 Turkey
# 30439           Luck Zogbé             3911          Cote d'Ivoire
# 30443      Mateus Lusuardi             8970                 Brazil
# 30455     Mahamadou Nagida              273               Cameroon
# 30457          Amadou Koné             1421          Cote d'Ivoire
#
#       date_of_birth    position   foot  height_in_cm  market_value_in_eur  \
# 0        1978-06-09      Attack  right         184.0            1000000.0
# ...

# %%
players_df_filtered.to_csv('data/filtered/players_filtered.csv')

# %% [markdown]
# # Appearances

# %%
appearances_df.head()
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0   2231978_38004  2231978      38004             853                     235
# 1   2233748_79232  2233748      79232            8841                    2698
# 2   2234413_42792  2234413      42792            6251                     465
# 3   2234418_73333  2234418      73333            1274                    6646
# 4  2234421_122011  2234421     122011             195                    3008
#
#          date       player_name competition_id  yellow_cards  red_cards  \
# 0  2012-07-03  Aurélien Joachim            CLQ             0          0
# 1  2012-07-05    Ruslan Abyshov            ELQ             0          0
# 2  2012-07-05       Sander Puri            ELQ             0          0
# 3  2012-07-05   Vegar Hedenstad            ELQ             0          0
# 4  2012-07-05  Markus Henriksen            ELQ             0          0
#
#    goals  assists  minutes_played
# ...

# %%
columns_appearances = [
    'player_id',
    'yellow_cards',
    'red_cards',
    'goals',
    'assists',
    'minutes_played' 
]

appearances_df_filtered = appearances_df[columns_appearances]

# in one table, 1. how many games he played?, 2. sum of minutes played, 3. average minutes per game, 4. sum of cards, average, etc, age, wiel alt ist er heute,

# %%
player_ids = players_df_filtered['player_id'].unique()
len(player_ids)
# Out:
# 10992

# %%
appearances_df_filtered = appearances_df[appearances_df['player_id'].isin(player_ids)]

# %%
len(appearances_df)
# Out:
# 1530230

# %%
len(appearances_df_filtered)
# Out:
# 661855

# %%
appearances_df_filtered.to_csv('data/filtered/appearances_filtered.csv')

# %% [markdown]
# # Clubs

# %%
clubs_df.head()
# Out:
#    club_id          club_code                              name  \
# 0      105    sv-darmstadt-98  Sportverein Darmstadt 1898 e. V.
# 1    11127  ural-ekaterinburg             FK Ural Yekaterinburg
# 2      114  besiktas-istanbul         Beşiktaş Jimnastik Kulübü
# 3       12             as-rom        Associazione Sportiva Roma
# 4      148  tottenham-hotspur   Tottenham Hotspur Football Club
#
#   domestic_competition_id  total_market_value  squad_size  average_age  \
# 0                      L1                 NaN          31         26.5
# 1                     RU1                 NaN          26         27.5
# 2                     TR1                 NaN          31         27.3
# 3                     IT1                 NaN          27         26.5
# 4                     GB1                 NaN          26         25.4
#
#    foreigners_number  foreigners_percentage  national_team_players  \
# 0                 11                   35.5                      1
# ...

# %%
clubs_df_filtered = clubs_df[clubs_df['domestic_competition_id'].isin(competition_ids)]

# %%
len(clubs_df_filtered)
# Out:
# 169

# %%
len(clubs_df)
# Out:
# 426

# %%
columns_clubs = [
    'club_id', 
    'club_name', 
    'domestic_competition_id', 
    'net_transfer_record'
    
]

clubs_df_filtered = appearances_df[columns_appearances]

# %%
clubs_df_filtered.to_csv('data/filtered/clubs_filtered.csv')
